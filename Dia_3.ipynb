# %%
palabra = input("Que palabra desea usar?")

def variable_palabra():
    print(f"Impreso la variable '{palabra}'")

variable_palabra()
# Out:
# Impreso la variable 'palabra'

# %%
def letras (letra_1, letra_2):
    if letra_1 == letra_2:
        print("Las letras son iguales")
    
    else:
        print("Las letras son diferentes")

letras("a", "a")
letras("a", "b")
# Out:
# Las letras son iguales
# Las letras son diferentes

# %%
def palabras_letras (palabra, numero):
    letras_palabra = len(word)
    if letras_palabra = palabra == numero:
        return True

    else:
        return False

palabra = input("Coloca una palabra")
numero = int(input("Coloca un numero"))
# Out:
#   Cell In[19], line 3
#     if letras_palabra = palabra == numero:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
palabra_usuario1 = input("Elija una palabra")
palabra_usuario2 = input("Elija una palabra")
palabra_usuario3 = input("Elija una palabra")


lista_de_palabra1 = list(palabra_usuario1)

lista_de_palabra2 = list(palabra_usuario2)

lista_de_palabra3 = list(palabra_usuario3)

palabras_ingresadas = list(lista_de_palabras_primeras)


print(palabras_ingresadas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 6
#       2 palabra_usuario2 = input("Elija una palabra")
#       3 palabra_usuario3 = input("Elija una palabra")
# ----> 6 lista_de_palabras_primeras = list(palabra_usuario1, palabra_usuario2, palabra_usuario3)
#       8 palabras_ingresadas = list(lista_de_palabras_primeras)
#      10 print(palabras_ingresadas)
#
# TypeError: list expected at most 1 argument, got 3

# %%
grilla1 = "holis"
grilla2 = "hello"
grilla3 = "hallo"

def grilla_listas():
    lista_grilla1 = list(grilla1)
    lista_grilla2 = list(grilla2)
    lista_grilla3 = list(grilla3)
